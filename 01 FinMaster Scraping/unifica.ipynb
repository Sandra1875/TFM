# %%
import unittest
import sys
from pymongo import MongoClient
import hashlib
sys.path.append("..")
from scraper.scraper_selenium_remax import ScraperSeleniumRemax
from mongodb_dao.mongodb_data_recorder import MongoDBDataRecorder
import pandas as pd

# %%
client =  MongoClient('mongodb+srv://Sandra:Sandra@cluster0.xs4os.mongodb.net/real-state-db?retryWrites=true&w=majority')
db = client['real-state-db']
    
origen_collection= db.Remax
destino_collection= db.RemaxDetalle

# %%
import os
datos = pd.DataFrame(destino_collection.find({}, {'estado', 'direccion',
          'NoAmbientes',
          'NoDormitorios',
          'NoBanos',
          'NoEstacionamientos',
          'Total M²',
          'Terreno',
          'Area Construcción',
          'Ano Construcción',
          'Mes Construcción',
          'Estacionamiento',
          'Jardin',
          'Terraza',
          'MedidorAgua',
          'Avenida',
          'Colegio',
          'Vista Panoramica',
          'Amoblado',
          'Moderno',
          'Renovado',
          'Seguridad',
          'Alcantarillado',
          'Agua',
          'Walk',
          'Terraza',
          'MedidorAgua',
          'Comercios',
          'Hospital',
          'JInfantiles',
          'Residencial',
          'TransporteP',
          'Trole',
          'Concurrida',
          'Alarma',
          'Barbecue',
          'Balcon',
          'Bodega',
          'Chimenea',
          'Cocina',
          'Gimnasio',
          'Iglesia',
          'Cable',
          'Aestrenar',
          'Ascensor',
          'GasCentral',
          'CasaColonial',
          'Turismo',
          'Aeropuerto',
          'Autopista',
          'Montania',
          'ZonaTranquila',
          'Generador',
          'EdificioN',
          'Conserje',
          'Concreto',
          'Playa',
          'Reconstruido',
          'Piscina',
          'Gimnasio',
          'Jacuzzi', 'NoAmb', 'NoBan', 'NoDorm', 'NoMetros', 'estadoTran', 'lat', 'lng',
          'precio', 'price' , 'tipoInv', 'tipoTran', 'titulo'}))
ruta_output = os.path.join('res', 'o_datos1.dat')
datos.to_csv(ruta_output, sep=';', na_rep='null')

# %%
ruta_users = os.path.join("res", "o_datos1.dat")
users_dataset = pd.read_csv(ruta_users, sep=';', index_col=0, engine='python')
users_dataset.sample(2)
# Out:
#                                                     _id estado  \
# 3162  af06bc3f8877a0582e02ccd270acd74b854e8a0e---Usa...  Usada
# 475   e67fabc91e74072ab5576bf68d8e3ddf49834fd1------...    NaN
#
#                                               direccion  Aeropuerto  \
# 3162  LA CERAMICA - LA CERAMICA - La Ceramica - Tumb...           0
# 475   Portal de Cumbaya 2 - Cumbaya Cabecera - Cumba...           0
#
#       Aestrenar  Agua  Alarma  Alcantarillado  Amoblado  Ano Construcción  \
# 3162          0     0       0               0         0              2014
# 475           0     0       0               0         0              1996
#
#       ...  NoDorm  NoMetros  estadoTran       lat        lng    precio  \
# 3162  ...       0       193         NaN  0.000000   0.000000  235000.0
# 475   ...       0       540         NaN -0.205392 -78.420963  590000.0
#
#         price  tipoInv  tipoTran  \
# 3162  235,000     Casa  De Venta
# 475   590,000     Casa  De Venta
#
# ...

# %%
cantidad =0
for scraped_data in origen_collection.find({},{'id', 'tipo', 'estVenta', 'lat', 
                                               'lng', 'tipoinv', 'titulo', 'prize', 'precio', 
                                              'dormitorios', 'meters', 'banios', 'amb'}):
    id_propiedad = str(scraped_data['id'])
    id_tipo = str(scraped_data['tipo'])
    id_estVenta = str(scraped_data['estVenta'])
    id_lat = str(scraped_data['lat'])
    id_lng = str(scraped_data['lng'])
    id_tipoinv = str(scraped_data['tipoinv'])
    id_titulo = str(scraped_data['titulo'])
    id_prize = str(scraped_data['prize'])
    id_precio = str(scraped_data['precio'])
    id_dormitorios = str(scraped_data['dormitorios'])
    id_meters = str(scraped_data['meters'])
    id_banios = str(scraped_data['banios'])
    id_amb = str(scraped_data['amb'])
    print('actualizando :' + id_propiedad)
    destino_collection.update_many({'id1' : id_propiedad},{'$set': {'tot' : int(1), 
                                                                  'tipoTran': id_tipo,
                                                                  'estadoTran': id_estVenta,
                                                                  'lat': float(id_lat),
                                                                  'lng': float(id_lng),
                                                                  'tipoInv': id_tipoinv,
                                                                  'titulo': id_titulo,
                                                                  'price':id_prize,
                                                                  'precio': float(id_precio),
                                                                  'NoDorm': id_dormitorios,
                                                                  'NoMetros': id_meters,
                                                                  'NoBan': id_banios,
                                                                  'NoAmb': id_amb
                                                                         }})
# Out:
# actualizando :890561001-20
# actualizando :890191119-37
# actualizando :890191233-51
# actualizando :890321246-290
# actualizando :890551049-9
# actualizando :890191331-31
# actualizando :890191330-54
# actualizando :890191030-209
# actualizando :890191386-44
# actualizando :890321274-22
# actualizando :890191234-24
# actualizando :890191289-14
# actualizando :890321233-92
# actualizando :890321290-21
# actualizando :890321297-11
# actualizando :890091244-94
# actualizando :890091210-100
# actualizando :890321246-208
# actualizando :890321317-5
# actualizando :890191424-3
# actualizando :890441024-44
# actualizando :890191030-175
# actualizando :890551020-623
# actualizando :890441118-85
# actualizando :890091462-46
# actualizando :890191232-98
# actualizando :890091244-75
# actualizando :890231001-354
# actualizando :890231001-349
# actualizando :890231001-350
# actualizando :890091346-40
# actualizando :890091349-24
# actualizando :890111089-274
# actualizando :890091511-31
# ...
