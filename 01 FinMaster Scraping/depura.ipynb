# %%
import unittest
import sys
from pymongo import MongoClient
import hashlib
sys.path.append("..")
from scraper.scraper_selenium_remax import ScraperSeleniumRemax
from mongodb_dao.mongodb_data_recorder import MongoDBDataRecorder
import pandas as pd

# %%
client =  MongoClient('mongodb+srv://Sandra:Sandra@cluster0.xs4os.mongodb.net/real-state-db?retryWrites=true&w=majority')
db = client['real-state-db']
    
scrapped_data_collection= db.RemaxDetalle
Update_collection= db.RemaxDetalle

# %%
Update_collection.delete_many({'id' : ''})

# %%
cantidad =0
for scraped_data in scrapped_data_collection.find({'Jacuzzi':{'$ne': '' }},{'id1', 'atributos', 'caracteristicas'}):
    dic = str(scraped_data['atributos']).split(')')
    id_propiedad = str(scraped_data['id1'])
    encontro = False
    contruccion = False
    NoAmbientes=0
    NoDormitorios=0
    banios=0
    m2=""
    anio=0
    estacionamientos=0
    terreno=""
    contruccionm2=""
    mes=0
    for d in dic:
        inicio = d.find(',', d.find(':'))
        if encontro:
            terreno = d[inicio+5:-1]
            encontro=False
        elif contruccion:
            contruccionm2t = d[inicio+5:-1]
            if len(contruccionm2t)>0:
                contruccionm2=float(contruccionm2t.replace(',',''))
            else:
                contruccionm2=0
            contruccion=False
        elif 'Total de Ambientes' in d:            
            NoAmbientes=d[inicio+3:-1]
        elif 'Num. de Dormitorios' in d:
            NoDormitorios=d[inicio+3:-1]
        elif 'Baños' in d:            
            banios=d[inicio+3:-1]
        elif 'Total M²' in d:
            m2t=d[inicio+3:-1]
            if len(m2t)>0:
                m2=float(m2t.replace(',',''))
            else:
                m2=0
        elif 'Año Construcción' in d:
            anio=d[inicio+3:-1]
        elif 'Terreno:' in d:
            encontro = False
        elif 'Terreno' in d:
            encontro = True
        elif 'Estacionamientos' in d:
            estacionamientos=d[inicio+3:-1]
        elif 'Area Construcción' in d:
            contruccion = True
        elif 'Año/Mes de Construcción' in d:
            aniomes=d[inicio+3:-1]
            if len(aniomes)>4:
                anio = aniomes[0:4]
                mes=aniomes[5:7]
        else:
            if len(d)>5:
                print('atributos: ' + d)
    cantidad+=1
    NoEsta=False
    Jardin =False
    Terraza=False
    vista=False
    Amoblado=False
    Moderno=False
    Renovado =False
    Seguridad=False
    Agua=False
    Alcantarillado=False
    Medidor=False
    Walk=False
    Avenida=False
    Colegio=False
    Comercios=False
    Hospital=False
    JInfantiles=False
    Residencial=False
    TransporteP=False
    Trole=False
    Concurrida=False
    Alarma=False
    Barbecue=False
    Balcon=False
    Bodega=False
    Chimenea=False
    Cocina=False
    Gimnasio=False
    Iglesia=False
    Cable=False
    Aestrenar=False
    Ascensor=False
    GasCentral=False
    CasaColonial=False
    Turismo=False
    Aeropuerto=False
    Autopista=False
    Montania=False
    ZonaTranquila=False
    Generador=False
    EdificioN=False
    Conserje=False
    Concreto=False
    Playa=False
    Reconstruido=False
    Piscina=False
    Gimnasio=False
    Jacuzzi=False
    caract = str(scraped_data['caracteristicas']).split(':')
    for c in caract:
        if 'Estacionamiento' in c:            
            NoEsta=True
        elif 'Jardín' in c:
            Jardin=True
        elif 'Terraza' in c:            
            Terraza=True
        elif 'Vista Panorámica' in c:
            vista=True
        elif 'Vistas Panorámicas' in c:
            vista=True            
        elif 'Amoblado' in c:
            Amoblado=True
        elif 'Moderno' in c:
            Moderno=True
        elif 'Renovado' in c:
            Renovado=True
        elif ('Seguridad - Vigilancia' in c) or ('Sistema de Seguridad' in c) or ('Seguridad - Sistema' in c):            
            Seguridad=True
        elif 'Agua potable' in c:
            Agua=True
        elif 'Alcantarillado' in c:
            Alcantarillado=True
        elif 'Medidor de Agua Individual' in c:
            Medidor=True
        elif 'Walk-In Closet' in c:
            Walk=True
        elif 'Cerca de Avenida' in c:
            Avenida=True
        elif 'Colegio cercano' in c:
            Colegio=True
        elif 'Comercios cercanos' in c:
            Comercios=True
        elif 'Hospital cercano' in c:
            Hospital=True       
        elif 'Junto Parque  con Juegos Infantiles' in c:
            JInfantiles=True
        elif 'Residencial' in c:
            Residencial=True
        elif 'Transporte Público Cercano' in c:
            TransporteP=True
        elif 'Trole cerca' in c:
            Trole=True
        elif 'Zona Concurrida' in c:
            Concurrida=True
        elif 'Sistema de Alarma' in c:
            Alarma=True
        elif ('Area Barbecue' in c) or ('Parrilla/BBQ' in c):
            Barbecue=True
        elif 'Balcón' in c:
            Balcon=True       
        elif 'Bodega' in c:
            Bodega=True
        elif 'Chimenea a leña' in c:
            Chimenea=True
        elif 'Cocina abierta' in c:
            Cocina=True
        elif 'Gimnasio cercano' in c:
            Gimnasio=True
        elif 'Iglesia cerca' in c:
            Iglesia=True            
        elif 'Cable' in c:
            Cable=True   
        elif 'A estrenar' in c:
            Aestrenar=True       
        elif 'Ascensor' in c:
            Ascensor=True
        elif 'Gas Central' in c:
            GasCentral=True
        elif ('Casa Colonial' in c) or ('Centro Histórico' in c):
            CasaColonial=True
        elif 'Zona Turística' in c:
            Turismo=True
        elif 'Cerca de Aeropuerto' in c:
            Aeropuerto=True            
        elif 'Cerca de Autopista' in c:
            Autopista=True   
        elif ('Vista a la Montaña' in c) or ('Montañas' in c):
            Montania=True
        elif 'Zona Tranquila' in c:
            ZonaTranquila=True            
        elif 'Generador Eléctrico' in c:
            Generador=True
        elif 'Edificio Nuevo' in c:
            EdificioN=True            
        elif 'Conserje Disponible' in c:
            Conserje=True   
        elif 'Concreto' in c:
            Concreto=True    
        elif 'Reconstruído' in c:
            Reconstruido=True   
        elif 'Piscina' in c:
            Piscina=True   
        elif 'Gimnasio' in c:
            Gimnasio=True 
        elif 'Jacuzzi' in c:
            Jacuzzi=True 
        elif ('Playa' in c) or ('Vista al Mar' in c) or ('Cerca a la Costa' in c):
            Playa=True   
    print('actualizando :' + id_propiedad)
    Update_collection.update_many({'id1' : id_propiedad},{'$set': {'proc' : int(1), 
                                                                  'NoAmbientes': int(NoAmbientes),
                                                                  'NoDormitorios': int(NoDormitorios),
                                                                  'NoBanos': int(banios),
                                                                  'NoEstacionamientos': int(estacionamientos),
                                                                  'Total M²': m2,
                                                                  'Terreno': terreno,
                                                                  'Area Construcción':contruccionm2,
                                                                  'Ano Construcción': int(anio),
                                                                  'Mes Construcción': int(mes),
                                                                  'Estacionamiento': int(NoEsta),
                                                                  'Jardin': int(Jardin),
                                                                  'Terraza': int(Terraza),
                                                                  'MedidorAgua': int(Medidor),
                                                                  'Avenida': int(Avenida),
                                                                  'Colegio': int(Colegio),
                                                                  'Vista Panoramica': int(vista),
                                                                  'Amoblado': int(Amoblado),
                                                                  'Moderno': int(Moderno),
                                                                  'Renovado': int(Renovado),
                                                                  'Seguridad': int(Seguridad),
                                                                  'Alcantarillado': int(Alcantarillado),
                                                                  'Agua': int(Agua),
                                                                  'Walk': int(Walk),
                                                                  'Terraza': int(Terraza),
                                                                  'MedidorAgua': int(Medidor),
                                                                  'Comercios': int(Comercios),
                                                                  'Hospital': int(Hospital),
                                                                  'JInfantiles': int(JInfantiles),
                                                                  'Residencial': int(Residencial),
                                                                  'TransporteP': int(TransporteP),
                                                                  'Trole': int(Trole),
                                                                  'Concurrida': int(Concurrida),
                                                                  'Alarma': int(Alarma),
                                                                  'Barbecue': int(Barbecue),
                                                                  'Balcon': int(Balcon),
                                                                  'Bodega': int(Bodega),
                                                                  'Chimenea': int(Chimenea),
                                                                  'Cocina': int(Cocina),
                                                                  'Gimnasio': int(Gimnasio),
                                                                  'Iglesia': int(Iglesia),
                                                                  'Cable': int(Cable),
                                                                  'Aestrenar': int(Aestrenar),
                                                                  'Ascensor': int(Ascensor),
                                                                  'GasCentral': int(GasCentral),
                                                                  'CasaColonial': int(CasaColonial),
                                                                  'Turismo': int(Turismo),
                                                                  'Aeropuerto': int(Aeropuerto),
                                                                  'Autopista': int(Autopista),
                                                                  'Montania': int(Montania),
                                                                  'ZonaTranquila': int(ZonaTranquila),
                                                                  'Generador': int(Generador),
                                                                  'EdificioN': int(EdificioN),
                                                                  'Conserje': int(Conserje),
                                                                  'Concreto': int(Concreto),
                                                                  'Playa': int(Playa),
                                                                  'Reconstruido': int(Reconstruido),
                                                                  'Piscina': int(Piscina),
                                                                  'Gimnasio': int(Gimnasio),
                                                                  'Jacuzzi': int(Jacuzzi)
                                                                         }})    
    if cantidad>1000:
        break
# Out:
# actualizando :890091392-13
# actualizando :890091392-20
# actualizando :890091392-21
# actualizando :890091392-6
# actualizando :890091392-9
# actualizando :890091395-36
# actualizando :890091395-7
# actualizando :890091409-10
# actualizando :890091409-12
# actualizando :890091409-15
# actualizando :890091409-23
# actualizando :890091409-26
# actualizando :890091409-28
# actualizando :890091409-34
# actualizando :890091409-3
# actualizando :890321297-10
# actualizando :890321297-6
# actualizando :890351018-173
# actualizando :890351018-318
# actualizando :890491010-47
# actualizando :890551018-493
# actualizando :890551018-513
# actualizando :890551020-600
# actualizando :890551020-623
# actualizando :890551023-320
# actualizando :890551023-374
# actualizando :890551027-206
# actualizando :890551027-213
# actualizando :890551032-83
# actualizando :890551039-12
# actualizando :890551039-29
# actualizando :890551041-1001
# actualizando :890551041-1002
# actualizando :890551041-989
# ...
