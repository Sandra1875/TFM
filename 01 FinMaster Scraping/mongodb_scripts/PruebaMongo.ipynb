# %%
import unittest
import sys
from pymongo import MongoClient
import hashlib
sys.path.append("..")
from scraper.scraper_selenium_remax import ScraperSeleniumRemax
from mongodb_dao.mongodb_data_recorder import MongoDBDataRecorder

# %%
client =  MongoClient('mongodb+srv://Sandra:Sandra@cluster0.xs4os.mongodb.net/real-state-db?retryWrites=true&w=majority')
db = client['real-state-db']
    
scrapped_data_collection= db.Remax
cantidad = 2
#({"_id":2});
#.pretty()
inicio = 4
fin = 1000

for scraped_data in scrapped_data_collection.find({ 'deta': {'$ne': 1 } },{'id', 'url_element'}):
    print("url: "+ scraped_data['id'])
    if cantidad > inicio:
        scraper_remax= ScraperSeleniumRemax([scraped_data['url_element']])        
        scraper_remax.get_data(scraped_data['id'])
        data_remax = scraper_remax.data
        mongodb_data_recorder = MongoDBDataRecorder(data_remax)
        mongodb_data_recorder.post_detalle()
        scrapped_data_collection.update_many({'id' : scraped_data['id']},{'$set': {'deta' : int(1)}}) 
    if cantidad > fin:
        break
    cantidad +=1
        
print("Total: "+str(cantidad))
# Out:
# url: 890491027-57
# url: 890351021-101
# url: 890351041-21
# url: 890111079-98
# obtaining data from https://www.remax.com.ec/es-ec/propiedades/terreno/de-venta/samborondon/samborondon/890111079-98?LFPNNSource=Search&cKey=890111079-98&HighlightingWords=terreno
# saving :
# url: 890251006-690
# obtaining data from https://www.remax.com.ec/es-ec/propiedades/terreno/de-venta/conocoto/890251006-690?LFPNNSource=Search&cKey=890251006-690&HighlightingWords=terreno
# saving :ID: 890251006-690
# url: 890391110-37
# obtaining data from https://www.remax.com.ec/es-ec/propiedades/terreno/de-venta/samborondon/km-75-via-samborondon/890391110-37?LFPNNSource=Search&cKey=890391110-37&HighlightingWords=terreno
# saving :ID: 890391110-37
# url: 890191205-134
# obtaining data from https://www.remax.com.ec/es-ec/propiedades/terreno/de-venta/tumbaco/juan-jose-flores/890191205-134?LFPNNSource=Search&cKey=890191205-134&HighlightingWords=terreno
# saving :ID: 890191205-134
# url: 890251101-77
# ...
